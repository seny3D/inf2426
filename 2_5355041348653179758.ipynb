# %%
import matplotlib.pyplot as plt

# %%
import random
import time


class TooMuch(Exception):
    pass
class YouWin(Warning):
    pass
c = []
d = []
Luse=0
Win = 0
while Luse+Win<1000000:
    a = random.randint(1,999)
    #a = int(input('Какое число в массиве?: '))
    while a > 20:
        a = random.randint(1, 21)
        #print('а не может быть больше 20, a = ', a)

    k = []
    notpizdez = 0
    run = True
    while run:
        if notpizdez > 10:
            #print('You dont have luch')
            break
            # raise TooMuch('You dont have luck')
        else:
            if a in k:
                #print(f'Yes! {a} in this massive!')
                #print(k)
                run = False
            else:
                #print('false')
                #print('Плохой массив', k)
                for x in range(1):
                    k.append(random.randint(1, 21))
            notpizdez += 1
    if notpizdez > 10:
        #print('LOSE!')
        Luse+=1
    else:
        #print('Congratulation!')
        Win+=1
    #print("Luse:Win")
    #print(f'{Luse}:{Win}')
    if (Luse+Win)%200 == 0:
        c.append(Win/(Luse+Win))
        d.append(Win+Luse)
    # raise YouWin('You founded a number what did you want!')
plt.plot(d,c)
